# %% [markdown]
# ## merge corpora
#
# merge the AMEX and SPAADIA corpora and do some quick fixes

# %%
# %matplotlib inline

import codecs
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
amex = pd.read_csv('../00_data/amex_parsed.csv')
spaadia = pd.read_csv('../00_data/spaadia_parsed.csv')

# %%
# get max conv in spaadia
m = max([int(i) for i in spaadia['dialog_num'].tolist()])
m
# Out:
# 34

# %%
# merge corpus
new_amex = [int(i) + m + 1 for i in amex['dialog_num'].tolist()]
amex['dialog_num'] = new_amex
corpus = spaadia.append(amex).copy()

# %%
# postprocessing clean-up

# A: clean up speech acts
spacts = corpus['speech_act'].tolist()
for idx, sa in enumerate(spacts):
    if sa == 'direct-expressWisht':
        spacts[idx] = 'direct-expressWish'

corpus['speech_act'] = spacts

# %%
corpus.to_csv('../00_data/merged_corpus.csv', index=False)

# %%
corpus.columns
# Out:
# Index(['filename', 'dialog_num', 'turn_num', 'line_num', 'speaker', 'message',
#        'punct', 'sent_type', 'speech_act', 'topic'],
#       dtype='object')

# %%
sent_types = corpus['sent_type'].tolist()
print(len(set(sent_types)), 'unique sent types')
# Out:
# 10 unique sent types

# %%
for l in list(set(sent_types)):
    print(l)
# Out:
# imp
# q-yn
# decl
# q-wh
# frag
# address
# no
# exclam
# dm
# yes

# %%
speech_acts = corpus['speech_act'].tolist()
print(len(set(speech_acts)), 'unique speech acts')
# Out:
# 262 unique speech acts

# %%
Counter(speech_acts).most_common(20)
# Out:
# [('state', 1780),
#  ('acknowledge', 1744),
#  ('reqInfo', 1013),
#  ('init', 998),
#  ('refer', 938),
#  ('hesitate', 518),
#  ('reqConfirm', 371),
#  ('echo-refer', 299),
#  ('answer-state', 252),
#  ('answer-refer', 249),
#  ('hold', 223),
#  ('confirm-acknowledge', 206),
#  ('exclaim', 178),
#  ('thank', 173),
#  ('answer-acknowledge', 162),
#  ('approve', 161),
#  ('stateCondition', 156),
#  ('stateIntent', 150),
#  ('predict', 150),
#  ('stateConstraint', 149)]

# %%
corpus['speech_act'].value_counts().plot(kind='bar')

# %%
topics = corpus['topic'].tolist()
print(len(set(topics)), 'unique topics')
# Out:
# 705 unique topics

# %%
Counter(topics).most_common(20)
# Out:
# [('none', 7868),
#  ('enum', 774),
#  ('time', 332),
#  ('number', 252),
#  ('day', 217),
#  ('location', 126),
#  ('creditcard', 125),
#  ('name', 117),
#  ('time-enum', 108),
#  ('journey', 97),
#  ('location_US', 91),
#  ('fare-enum', 79),
#  ('seat', 77),
#  ('fare', 76),
#  ('verify', 62),
#  ('airline', 62),
#  ('availability', 58),
#  ('month-date', 50),
#  ('time-day', 49),
#  ('time-arrival', 47)]

# %%
sents = corpus['message'].tolist()
sentlens = [len(str(sent)) for sent in sents]
print('avg sent length:', sum(sentlens)/len(sentlens))
# Out:
# avg sent length: 19.079462482522914
